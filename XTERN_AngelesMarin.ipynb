# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file_path = '/Users/XTERN/XTern 2024 Artificial Intelegence Data Set - Xtern_TrainData.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#      Year                    Major                University  Time  \
# 0  Year 2                  Physics  Indiana State University    12
# 1  Year 3                Chemistry     Ball State University    14
# 2  Year 3                Chemistry         Butler University    12
# 3  Year 2                  Biology  Indiana State University    11
# 4  Year 3  Business Administration         Butler University    12
#
#                                                Order
# 0                               Fried Catfish Basket
# 1                                    Sugar Cream Pie
# 2                                 Indiana Pork Chili
# 3                               Fried Catfish Basket
# 4  Indiana Corn on the Cob (brushed with garlic b...

# %% [markdown]
# ### Quickly viewing first few rows of data to gain insight on range and tendencies.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        5000 non-null   object
#  1   Major       5000 non-null   object
#  2   University  5000 non-null   object
#  3   Time        5000 non-null   int64
#  4   Order       5000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 195.4+ KB

# %% [markdown]
# ### Understanding the data:
# - no inconsistent data types

# %%
df.describe(include=['object'])
# Out:
#           Year      Major         University            Order
# count     5000       5000               5000             5000
# unique       4         20                 10               10
# top     Year 3  Chemistry  Butler University  Sugar Cream Pie
# freq      2719        640               1614              512

# %% [markdown]
# ### Provides info about distribution, tendencies, and variability of data

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Time'}>]], dtype=object)

# %% [markdown]
# ### Normal distribution with bell-shape for 'Time'

# %%
pd.crosstab(df['Major'], df['Order'])
# Out:
# Order                    Breaded Pork Tenderloin Sandwich  \
# Major
# Accounting                                             14
# Anthropology                                            0
# Astronomy                                              84
# Biology                                                21
# Business Administration                                61
# Chemistry                                              45
# Civil Engineering                                       0
# Economics                                              18
# Finance                                                24
# Fine Arts                                               0
# International Business                                  9
# Marketing                                              67
# Mathematics                                            85
# Mechanical Engineering                                  4
# Music                                                   0
# ...

# %% [markdown]
# ### Frequency of combinations between Major and Order

# %%
sns.countplot(data= df, x ='University', hue= 'Order')
# Out:
# <Axes: xlabel='University', ylabel='count'>

# %% [markdown]
# ### Visualizes relationship between University and Order

# %%
sns.catplot(data=df, x="Year", y="Order")

# %% [markdown]
# ### Visualizes the distribution in Year and Order
